# %%
import pandas as pd

# %%
data = pd.read_csv('07-06-2021-TO-07-06-2026-ADANIENT-ALL-N.csv')
data.head()
# Out:
#    Symbol   Series         Date   Prev Close   Open Price   High Price    \
# 0  ADANIENT       BL  05-Jun-2026     2,435.60     2,913.40     2,913.40
# 1  ADANIENT       EQ  05-Jun-2026     2,972.80     2,992.00     3,059.80
# 2  ADANIENT       EQ  04-Jun-2026     2,925.60     2,920.00     2,983.00
# 3  ADANIENT       EQ  03-Jun-2026     2,968.10     2,960.00     2,965.00
# 4  ADANIENT       EQ  02-Jun-2026     2,909.40     2,885.00     2,975.00
#
#   Low Price   Last Price   Close Price   Average Price   \
# 0    2,913.40     2,913.40      2,913.40       2,913.40
# 1    2,921.80     3,043.00      3,048.20       3,015.26
# 2    2,918.10     2,977.90      2,972.80       2,962.79
# 3    2,888.10     2,929.00      2,925.60       2,922.19
# 4    2,865.20     2,972.00      2,968.10       2,918.50
#
#   Total Traded Quantity          Turnover ₹   No. of Trades    \
# 0             1,64,39,984  47,89,62,49,385.60               1
# ...

# %%
data.columns
# Out:
# Index(['Symbol  ', 'Series  ', 'Date  ', 'Prev Close  ', 'Open Price  ',
#        'High Price  ', 'Low Price  ', 'Last Price  ', 'Close Price  ',
#        'Average Price ', 'Total Traded Quantity  ', 'Turnover ₹  ',
#        'No. of Trades  ', 'Deliverable Qty  ', '% Dly Qt to Traded Qty  '],
#       dtype='object')

# %%
data.columns = data.columns.str.strip()

# %%
data = data.reset_index(drop=True)

# %%
data.dtypes
# Out:
# Symbol                    object
# Series                    object
# Date                      object
# Prev Close                object
# Open Price                object
# High Price                object
# Low Price                 object
# Last Price                object
# Close Price               object
# Average Price             object
# Total Traded Quantity     object
# Turnover ₹                object
# No. of Trades             object
# Deliverable Qty           object
# % Dly Qt to Traded Qty    object
# dtype: object

# %%
data.tail(10)
# Out:
#         Symbol Series         Date Prev Close Open Price High Price Low Price  \
# 1242  ADANIENT     EQ  18-Jun-2021   1,367.70   1,350.00   1,504.00  1,332.55
# 1243  ADANIENT     EQ  17-Jun-2021   1,448.30   1,380.00   1,436.00  1,303.50
# 1244  ADANIENT     EQ  16-Jun-2021   1,538.85   1,510.00   1,538.20  1,409.30
# 1245  ADANIENT     EQ  15-Jun-2021   1,501.45   1,550.95   1,572.60  1,477.20
# 1246  ADANIENT     EQ  14-Jun-2021   1,601.60   1,441.45   1,529.95  1,201.20
# 1247  ADANIENT     EQ  11-Jun-2021   1,612.00   1,615.10   1,620.10  1,575.25
# 1248  ADANIENT     EQ  10-Jun-2021   1,594.65   1,612.00   1,630.00  1,591.00
# 1249  ADANIENT     EQ  09-Jun-2021   1,636.45   1,640.00   1,649.45  1,571.85
# 1250  ADANIENT     EQ  08-Jun-2021   1,624.30   1,633.00   1,668.00  1,602.45
# 1251  ADANIENT     EQ  07-Jun-2021   1,700.95   1,715.00   1,717.20  1,613.00
#
#      Last Price Close Price Average Price Total Traded Quantity  \
# ...

# %%
data.head(10)
# Out:
#      Symbol Series         Date Prev Close Open Price High Price Low Price  \
# 0  ADANIENT     BL  05-Jun-2026   2,435.60   2,913.40   2,913.40  2,913.40
# 1  ADANIENT     EQ  05-Jun-2026   2,972.80   2,992.00   3,059.80  2,921.80
# 2  ADANIENT     EQ  04-Jun-2026   2,925.60   2,920.00   2,983.00  2,918.10
# 3  ADANIENT     EQ  03-Jun-2026   2,968.10   2,960.00   2,965.00  2,888.10
# 4  ADANIENT     EQ  02-Jun-2026   2,909.40   2,885.00   2,975.00  2,865.20
# 5  ADANIENT     EQ  01-Jun-2026   2,937.40   2,949.90   2,955.70  2,891.10
# 6  ADANIENT     EQ  29-May-2026   2,973.10   2,987.80   2,995.00  2,926.80
# 7  ADANIENT     EQ  27-May-2026   2,969.30   2,982.00   3,027.50  2,944.00
# 8  ADANIENT     EQ  26-May-2026   2,849.70   2,846.00   2,979.40  2,825.00
# 9  ADANIENT     EQ  25-May-2026   2,717.30   2,739.80   2,858.80  2,739.30
#
#   Last Price Close Price Average Price Total Traded Quantity  \
# 0   2,913.40    2,913.40      2,913.40           1,64,39,984
# ...

# %%
equity = data[data['Series']=='EQ']

# %%
equity[equity['Date']>'18-Jun-2021']
# Out:
#         Symbol Series         Date Prev Close Open Price High Price Low Price  \
# 6     ADANIENT     EQ  29-May-2026   2,973.10   2,987.80   2,995.00  2,926.80
# 7     ADANIENT     EQ  27-May-2026   2,969.30   2,982.00   3,027.50  2,944.00
# 8     ADANIENT     EQ  26-May-2026   2,849.70   2,846.00   2,979.40  2,825.00
# 9     ADANIENT     EQ  25-May-2026   2,717.30   2,739.80   2,858.80  2,739.30
# 10    ADANIENT     EQ  22-May-2026   2,697.60   2,710.20   2,745.00  2,706.10
# ...        ...    ...          ...        ...        ...        ...       ...
# 1237  ADANIENT     EQ  25-Jun-2021   1,508.50   1,525.00   1,534.00  1,501.00
# 1238  ADANIENT     EQ  24-Jun-2021   1,504.75   1,509.95   1,519.00  1,488.05
# 1239  ADANIENT     EQ  23-Jun-2021   1,541.60   1,560.10   1,569.95  1,481.30
# 1240  ADANIENT     EQ  22-Jun-2021   1,540.00   1,554.05   1,582.00  1,531.80
# 1241  ADANIENT     EQ  21-Jun-2021   1,487.50   1,490.00   1,582.00  1,444.85
#
# ...

# %%
data['Series'].value_counts()
# Out:
# Series
# EQ    1240
# BL      12
# Name: count, dtype: int64

# %%
cols = [
    'Open Price',
    'High Price',
    'Low Price',
    'Close Price',
    'Last Price',
    'Average Price',
    'Prev Close',
    'Total Traded Quantity',
    'No. of Trades',
    'Deliverable Qty',

    
]

for col in cols:
    data[col] = (
        data[col]
        .astype(str)
        .str.replace(',', '',regex=False)
        .str.replace('_','',regex=False)
    )
    data[col] = pd.to_numeric(data[col], errors='coerce')

# %%
data.isnull().sum()
# Out:
# Symbol                     0
# Series                     0
# Date                       0
# Prev Close                 0
# Open Price                 0
# High Price                 0
# Low Price                  0
# Last Price                 0
# Close Price                0
# Average Price              0
# Total Traded Quantity      0
# Turnover ₹                 0
# No. of Trades              0
# Deliverable Qty           12
# % Dly Qt to Traded Qty     0
# dtype: int64

# %%
data.dtypes
# Out:
# Symbol                     object
# Series                     object
# Date                       object
# Prev Close                float64
# Open Price                float64
# High Price                float64
# Low Price                 float64
# Last Price                float64
# Close Price               float64
# Average Price             float64
# Total Traded Quantity       int64
# Turnover ₹                 object
# No. of Trades               int64
# Deliverable Qty           float64
# % Dly Qt to Traded Qty     object
# dtype: object

# %%
print(data['Last Price'].dtype)
# Out:
# float64

# %%
data['Last Price'].astype(str).unique()
# Out:
# array(['2913.4', '3043.0', '2977.9', ..., '1609.8', '1590.45', '1625.0'],
#       dtype=object)

# %%
data.head()
# Out:
#      Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0  ADANIENT     BL  05-Jun-2026      2435.6      2913.4      2913.4
# 1  ADANIENT     EQ  05-Jun-2026      2972.8      2992.0      3059.8
# 2  ADANIENT     EQ  04-Jun-2026      2925.6      2920.0      2983.0
# 3  ADANIENT     EQ  03-Jun-2026      2968.1      2960.0      2965.0
# 4  ADANIENT     EQ  02-Jun-2026      2909.4      2885.0      2975.0
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     2913.4      2913.4       2913.4        2913.40               16439984
# 1     2921.8      3043.0       3048.2        3015.26                5617327
# 2     2918.1      2977.9       2972.8        2962.79                1722991
# 3     2888.1      2929.0       2925.6        2922.19                1346112
# 4     2865.2      2972.0       2968.1        2918.50                2066890
#
#            Turnover ₹  No. of Trades  Deliverable Qty % Dly Qt to Traded Qty
# ...

# %%
data.isnull().sum()
# Out:
# Symbol                     0
# Series                     0
# Date                       0
# Prev Close                 0
# Open Price                 0
# High Price                 0
# Low Price                  0
# Last Price                 0
# Close Price                0
# Average Price              0
# Total Traded Quantity      0
# Turnover ₹                 0
# No. of Trades              0
# Deliverable Qty           12
# % Dly Qt to Traded Qty     0
# dtype: int64

# %%
data[data['No. of Trades']==1]
# Out:
#         Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0     ADANIENT     BL  05-Jun-2026     2435.60     2913.40     2913.40
# 17    ADANIENT     BL  14-May-2026     2462.00     2435.60     2435.60
# 137   ADANIENT     BL  18-Nov-2025     2558.70     2462.00     2462.00
# 224   ADANIENT     BL  14-Jul-2025     4008.85     2558.70     2558.70
# 886   ADANIENT     BL  14-Nov-2022     3580.70     4008.85     4008.85
# 893   ADANIENT     BL  03-Nov-2022     3309.80     3580.70     3580.70
# 901   ADANIENT     BL  25-Oct-2022     3246.25     3309.80     3309.80
# 912   ADANIENT     BL  11-Oct-2022     3455.75     3246.25     3246.25
# 917   ADANIENT     BL  03-Oct-2022     2698.40     3455.75     3455.75
# 956   ADANIENT     BL  08-Aug-2022     2499.40     2698.40     2698.40
# 967   ADANIENT     BL  25-Jul-2022     1458.70     2499.40     2499.40
# 1168  ADANIENT     BL  04-Oct-2021      505.00     1458.70     1458.70
#
# ...

# %%
equity.isnull().sum()
# Out:
# Symbol                    0
# Series                    0
# Date                      0
# Prev Close                0
# Open Price                0
# High Price                0
# Low Price                 0
# Last Price                0
# Close Price               0
# Average Price             0
# Total Traded Quantity     0
# Turnover ₹                0
# No. of Trades             0
# Deliverable Qty           0
# % Dly Qt to Traded Qty    0
# dtype: int64

# %%
equity.dtypes
# Out:
# Symbol                    object
# Series                    object
# Date                      object
# Prev Close                object
# Open Price                object
# High Price                object
# Low Price                 object
# Last Price                object
# Close Price               object
# Average Price             object
# Total Traded Quantity     object
# Turnover ₹                object
# No. of Trades             object
# Deliverable Qty           object
# % Dly Qt to Traded Qty    object
# dtype: object

# %%
cols = [
    'Open Price',
    'High Price',
    'Low Price',
    'Close Price',
    'Last Price',
    'Average Price',
    'Prev Close',
    'Total Traded Quantity',
    'No. of Trades',
    'Deliverable Qty',

    
]

for col in cols:
    equity[col] = (
        equity[col]
        .astype(str)
        .str.replace(',', '',regex=False)
        .str.replace('_','',regex=False)
    )
    equity[col] = pd.to_numeric(equity[col], errors='coerce')
# Out:
# /var/folders/lm/hds0rx213vscl9tcfy526l200000gn/T/ipykernel_2729/383860429.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   equity[col] = (
# /var/folders/lm/hds0rx213vscl9tcfy526l200000gn/T/ipykernel_2729/383860429.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   equity[col] = pd.to_numeric(equity[col], errors='coerce')
# /var/folders/lm/hds0rx213vscl9tcfy526l200000gn/T/ipykernel_2729/383860429.py:17: SettingWithCopyWarning:
# ...

# %%
data['Turnover ₹'] = pd.to_numeric(data['Turnover ₹'],errors = 'coerce')

# %%
equity = equity.rename(columns={'Turnover ₹':'Turnover'})

# %%
equity['Turnover'] = (
    equity['Turnover']
    .astype(str)
    .str.replace(',', '', regex=False)
)

equity['Turnover'] = pd.to_numeric(
    equity['Turnover'],
    errors='coerce'
)

# %%
equity
# Out:
#         Symbol Series       Date  Prev Close  Open Price  High Price  \
# 1     ADANIENT     EQ 2026-06-05     2972.80      2992.0     3059.80
# 2     ADANIENT     EQ 2026-06-04     2925.60      2920.0     2983.00
# 3     ADANIENT     EQ 2026-06-03     2968.10      2960.0     2965.00
# 4     ADANIENT     EQ 2026-06-02     2909.40      2885.0     2975.00
# 5     ADANIENT     EQ 2026-06-01     2937.40      2949.9     2955.70
# ...        ...    ...        ...         ...         ...         ...
# 1247  ADANIENT     EQ 2021-06-11     1612.00      1615.1     1620.10
# 1248  ADANIENT     EQ 2021-06-10     1594.65      1612.0     1630.00
# 1249  ADANIENT     EQ 2021-06-09     1636.45      1640.0     1649.45
# 1250  ADANIENT     EQ 2021-06-08     1624.30      1633.0     1668.00
# 1251  ADANIENT     EQ 2021-06-07     1700.95      1715.0     1717.20
#
#       Low Price  Last Price  Close Price  Average Price  \
# 1       2921.80     3043.00      3048.20        3015.26
# ...

# %%
equity.dtypes
# Out:
# Symbol                            object
# Series                            object
# Date                      datetime64[ns]
# Prev Close                       float64
# Open Price                       float64
# High Price                       float64
# Low Price                        float64
# Last Price                       float64
# Close Price                      float64
# Average Price                    float64
# Total Traded Quantity              int64
# Turnover                         float64
# No. of Trades                      int64
# Deliverable Qty                    int64
# % Dly Qt to Traded Qty            object
# dtype: object

# %%
equity['Date'] = pd.to_datetime(equity['Date'],errors = 'coerce')
